# %%
import tree.treeutils as tr
import tree.treeplots as trp
import numpy as np
import matplotlib.pyplot as plt
import pickle
from IPython.core.display import Image

# %%
work_dir="/home/hoseung/Work/data/AGN2/"
fn_tree = work_dir + "rhalo/rockstar_halos/trees/tree_0_0_0.dat"
fn_pickle_out = work_dir + "rhalo/tree.pickle"
f_pickle = open(fn_pickle_out, 'rb')
tt = pickle.load(f_pickle)

# %%
gals = tr.gal_list(tt)

fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(2,2,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-314b9ee76b5a> in <module>()
# ----> 1 gals = tr.gal_list(tt)
#       2
#       3 fig = plt.figure(figsize=(8,6))
#       4 ax1 = fig.add_subplot(2,2,1)
#
# AttributeError: 'module' object has no attribute 'gal_list'

# %%
cnt=0
#for thisgal in gals[cnt:]:
for thisgal in [1645120]:
    if (cnt % 10 == 0): print(cnt)
    tree = tr.get_main_tree(tt,thisgal)
    ind_tree = np.zeros(len(tree),dtype=np.int)

    for i in range(sum(x > 0 for x in tree)):
        #print i, np.where(data['id'] == tree[i])[0]
        ind_tree[i] = np.where(tt['id'] == tree[i])[0] # Why first element?
        
    td = tt[ind_tree]
    trp.trajectory_multi(td,thisgal,save=True,out_dir='./figs/')
    #trp.trajectory_multi(td,thisgal,save=True)
    #print "done \n"
    cnt +=1

    # As many times as you like, create a figure fig and save it:
#    fig = plt.figure()
#    pdf.savefig(fig)
    # When no figure is specified the current figure is saved
#    pdf.savefig()
# Out:
# 0

# %%
Image(filename='./figs/16451203D_multi.png')
