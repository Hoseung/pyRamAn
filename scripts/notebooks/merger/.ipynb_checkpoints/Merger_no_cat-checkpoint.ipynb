# %%
import tree.ctutils as ctu
from tree import treeutils
import numpy as np
import pickle

# Calculate merger event parameters
def find_merger(atree, idx=None, aexp_min=0.0):
    """
        find indices of merger event from a tree.
        (Full tree or main progenitor trunk)
    """
    if idx == None:
        idx = atree['id'][0]
        
    nprg = 1
    merger_list=[]

    i = 0
    while nprg > 0:
        idx = ctu.get_progenitors(atree, idx, main=True)[0]
        ind = np.where(atree['id'] == idx)[0]
        if atree['aexp'][ind] < aexp_min:
            break
        nprg = ctu.get_npr(atree, idx)

        if nprg > 1:
            merger_list.append(i)
        i +=1
    return merger_list


def merger_mass_ratio(atree, idx=None):
    """
    return mass ratio of the given merger event
    """
    if idx == None:
        idx = atree['id'][0]
        
    prgs = ctu.get_progenitors(atree, idx)
    
    # only for mergers
    if len(prgs) > 1:
        i_prgs = [np.where(atree['id'] == i)[0] for i in prgs]
        mass = []
        for iprg in i_prgs:
            mass.append(atree['m'])
    else:
        print("This is not a merger")
        return 0
    

def merger_properties_main_prg(atree, idx):
    """
        Calculate merger mass ratio for "one" merger event.

    if idx == None:
        if nout == None:
            print("Both idx and nout are missing")
            return
    else:
        if nout == None:
            nout = np.where(atree['id'] == idx)[0]

    idx = atree['id'][ind]
    """    

    #prgs = get_progenitors(atree, idx)
    #if len(prgs) > 1:
    #    i_prgs = [np.where(atree['id'] == i)[0] for i in prgs]
    
    i_prgs = np.where(atree['desc_id'] == idx)[0]
        
    print(i_prgs)
    id_prgs = atree['id'][i_prgs]
    mass_prgs = atree['m'][i_prgs]
    
    #mass_prgs_norm = mass_prgs / sum(mass_prgs)

    return mass_prgs






def distance_to(xc, xx):
    import numpy as np
    return np.sqrt([(xc[0] - xx[0])**2 + (xc[1] - xx[1])**2 + (xc[2] - xx[2])**2])[0]

def extract_halos_within(halos, i_center, info, dist_in_mpc=1.0):

    xc = halos['x'][i_center]
    yc = halos['y'][i_center]
    zc = halos['z'][i_center]

    xx = halos['x']
    yy = halos['y']
    zz = halos['z']

    dd = np.multiply(distance_to([xc,yc,zc], [xx,yy,zz]), info.pboxsize)

    return (dd < (dist_in_mpc))

# %%
import utils.match as mtc
import matplotlib.pyplot as plt
import pandas as pd
import tree.ctutils as ctu
import load 
import tree.halomodule as hmo


r_cluster_scale = 2.5
mstar_min = 2e9


nout_fi = 187

#Last merger
import matplotlib.pyplot as plt
nout_ini = 87 # recent merger after z =1.

# Load tree
is_gal = True

# all catalogs
verbose=False

#
most_recent_only = False

#clusters = ['39990', '36415', '10002', '05427', '36413', '01605']
clusters=['05427']

# final result arrays

gal_list=[]
mr_list=[]
nout_list=[]

#for cluster in clusters:
wdir = '/home/hoseung/Work/data/' + clusters[0] + '/'
#wdir = './'

alltrees = ctu.load_tree(wdir, is_gal=is_gal)

ft = alltrees.data[alltrees.data['nout'] == nout_fi]
#allgals = ft['id'][ft['m'] > 5e9]

info = load.info.Info(nout=nout_fi, base=wdir, load=True)

# %%
cat = pickle.load(open(wdir + 'catalog_GM/catalog' + str(nout_fi) + '.pickle', 'rb'))

# %%
final_gals_idx = cat['idx']

# %%
hhal = hmo.Halo(base=wdir, nout=nout_fi, halofinder='HM', info=info, load=True, is_gal=False)
i_center = np.where(hhal.data['np'] == max(hhal.data['np']))[0]
r_cluster = hhal.data['rvir'][i_center] * info.pboxsize

hh = hmo.Halo(base=wdir, nout=nout_fi, halofinder='HM', info=info, load=True, is_gal=is_gal)
i_center = np.where(hh.data['np'] == max(hh.data['np']))[0]
i_satellites = extract_halos_within(hh.data, i_center, info, dist_in_mpc = r_cluster * r_cluster_scale)
print("Total {0} galaxies \n{1} galaxies are selected".format(
      len(i_satellites),sum(i_satellites)))

# halos found inside the cluster and have complete tree back to nout_ini
large_enugh = hh.data['m'] > mstar_min
halo_list = hh.data['id'][i_satellites * large_enugh]
final_ids = ctu.check_tree_complete(alltrees.data, 87, nout_fi, halo_list, idx=False) # 87: z = 1

#final_gals_idx = [ft['id'][ft['Orig_halo_id'] == final_gal] for final_gal in final_ids]
#print(len(final_gals_idx), "halos left")
#ngals = len(final_gals_idx)
# Search for all galaxies that listed in the trees of final_gals
#all_gals_in_trees = all_gals(tt, final_gals_idx)
# Out:
# Loaded an extended tree
# Total 475 galaxies
# 384 galaxies are selected

# %%
i_center = np.where(hhal.data['np'] == max(hhal.data['np']))[0]

# %%
print(hhal.data[['x', 'y', 'z']][i_center])
# Out:
# [(0.39672601222991943, 0.7573985457420349, 0.2900131940841675)]

# %%
print(hh.data[['x', 'y', 'z']][i_center])
print(i_center)
# Out:
# [(0.41331130266189575, 0.7347573637962341, 0.2977367639541626)]
# [3]

# %%
final_ids
# Out:
# array([  4,  15,  24,  25,  29,  38,  43,  44,  45,  46,  47,  49,  58,
#         60,  62,  65,  68,  70,  76,  83,  84,  87,  90,  94,  96,  97,
#         98,  99, 100, 101, 102, 103, 105, 108, 111, 112, 113, 116, 119,
#        120, 123, 124, 138, 142, 143, 182], dtype=int32)

# %%
final_gals_idx
# Out:
# array([122682, 122704, 122737, 122761, 123024, 122676, 122697, 122727,
#        122755, 122824, 122675, 122696, 122724, 122754, 122787, 122680,
#        122701, 122729, 122759, 122899, 122683, 122705, 122739, 122766,
#        123025, 122674, 122695, 122717, 122753, 122784, 122679, 122698,
#        122728, 122758, 122835, 122670, 122692, 122710, 122750, 122773,
#        123047, 122672, 122693, 122714, 122751, 122776, 123051, 122673,
#        122694, 122715, 122752, 122780, 123054, 122668, 122690, 122709,
#        122747, 122772, 123039, 122665, 122687, 122706, 122745, 122767,
#        123037])

# %%
verbose=True
for idx in final_gals_idx:
    #gal = cat['id']
    if verbose: print("analyzing merger events of galaxy ", idx)

    # Convert halo id to tree id
    #idx = id2idx(alltrees.data, gal, 187)
    #idx = cat['idx']

    # full tree of a galaxy
    atree = ctu.extract_a_tree(alltrees.data, idx)

    # main progenitor tree
    mtree = ctu.extract_main_tree(alltrees.data, idx)

    x_nout = mtree['nout'].flatten()
    x_nout = x_nout[x_nout > nout_ini]

    mass_ratios_single = np.zeros(len(x_nout))
    for i, nout in enumerate(x_nout):
        # merger ratio
        i_prgs = np.where(atree['desc_id'] == mtree['id'][i])[0]

        # multiple prgs = merger
        if len(i_prgs) > 1:
            if verbose: print(" {} mergers at nout = {}".format(len(i_prgs), nout))
            id_prgs = atree['id'][i_prgs]
            mass_prgs = atree['m'][i_prgs]
            m_r = mass_prgs / max(mass_prgs)
            if verbose:
                print(" Mass ratios : ", m_r)
            mass_ratios_single[i] = max([mass_prgs[1:] / max(mass_prgs)][0])
        else:
            mass_ratios_single[i] = 0

    ind_ok = np.where(mass_ratios_single > 0.1)[0]
    #print("all ind_ok", ind_ok)
    if len(ind_ok) > 0:
        # if a satellite oscillates around the host, 
        # it could be identified as multiple mergers with short time interval. 
        # leave only the first passage / merger.
        good =[]
        for i in range(len(ind_ok)-1):
            if ind_ok[i+1] > ind_ok[i] + 2:
                good.append(ind_ok[i])
        good.append(ind_ok[-1])
        ind_ok = good
#        if most_recent_only:
#            ind_ok = max(ind_ok) # most recent 

#        print("  galaxy {}, Last nout {}, Merger ratio 1:{:.1f}".format(idx,
#                                                                     x_nout[ind_ok],
#                                                                       1./mass_ratios_single[ind_ok]))
        mr = 1./mass_ratios_single[ind_ok]

        gal_list.append(idx)
        mr_list.append(mr)
        nout_list.append(x_nout[ind_ok])


        
"""
fig, ax = plt.subplots(1)

ax.scatter(nout_list, mr_list)
ax.set_title("last merger Vs final lambda")
ax.set_ylabel(r"$\lambda _R$")
ax.set_xlabel("Last merger")
for i,gal_name in enumerate(gal_list):
    ax.text(nout_list[i]+0.5, mr_list[i]+0.1, str(gal_name))
plt.show()
"""
with open(wdir + 'merger_list.txt', 'w') as f:
#    print("Major mergers in this cluster")
    for gal, nout, mr in zip(gal_list, mr_list, nout_list):
        for ni, mi in zip(nout, mr):
            f.write("{}  {}  {} \n".format(gal, ni, mi))
# Out:
# analyzing merger events of galaxy  122682
#  2 mergers at nout = 164
#  Mass ratios :  [ 1.          0.09572643]
#  2 mergers at nout = 153
#  Mass ratios :  [ 1.          0.01230294]
# analyzing merger events of galaxy  122704
#  2 mergers at nout = 159
#  Mass ratios :  [ 1.          0.01187503]
#  2 mergers at nout = 144
#  Mass ratios :  [ 1.          0.01219987]
# analyzing merger events of galaxy  122737
#  2 mergers at nout = 143
#  Mass ratios :  [ 1.         0.3644174]
#  2 mergers at nout = 126
#  Mass ratios :  [ 0.  1.]
# analyzing merger events of galaxy  122761
# analyzing merger events of galaxy  123024
#  2 mergers at nout = 143
#  Mass ratios :  [ 1.          0.01320702]
# analyzing merger events of galaxy  122676
#  2 mergers at nout = 177
#  Mass ratios :  [ 1.         0.0012682]
#  3 mergers at nout = 162
#  Mass ratios :  [ 1.          0.00955946  0.00463072]
#  2 mergers at nout = 156
#  Mass ratios :  [ 1.          0.00161013]
#  2 mergers at nout = 145
#  Mass ratios :  [ 1.          0.01746978]
#  2 mergers at nout = 130
#  Mass ratios :  [ 1.          0.02789232]
#  2 mergers at nout = 120
#  Mass ratios :  [ 1.         0.0571281]
#  2 mergers at nout = 109
#  Mass ratios :  [ 1.          0.00470194]
#  3 mergers at nout = 107
#  Mass ratios :  [ 1.          0.08990412  0.05766567]
# analyzing merger events of galaxy  122697
#  2 mergers at nout = 97
#  Mass ratios :  [ 1.          0.01071596]
# analyzing merger events of galaxy  122727
#  2 mergers at nout = 124
#  Mass ratios :  [ 1.          0.02868886]
#  2 mergers at nout = 107
#  Mass ratios :  [ 1.          0.05469828]
#  2 mergers at nout = 95
#  Mass ratios :  [ 1.          0.34448332]
# analyzing merger events of galaxy  122755
#  3 mergers at nout = 118
#  Mass ratios :  [ 1.          0.08081762  0.02255662]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.04537653]
#  2 mergers at nout = 102
#  Mass ratios :  [ 1.          0.04315216]
# analyzing merger events of galaxy  122824
# analyzing merger events of galaxy  122675
# analyzing merger events of galaxy  122696
#  2 mergers at nout = 176
#  Mass ratios :  [ 1.          0.00912679]
#  2 mergers at nout = 112
#  Mass ratios :  [ 1.          0.15672405]
# analyzing merger events of galaxy  122724
#  2 mergers at nout = 176
#  Mass ratios :  [ 1.          0.06567579]
#  2 mergers at nout = 103
#  Mass ratios :  [ 1.          0.43125796]
#  2 mergers at nout = 96
#  Mass ratios :  [ 1.          0.90373486]
# analyzing merger events of galaxy  122754
# analyzing merger events of galaxy  122787
# analyzing merger events of galaxy  122680
#  2 mergers at nout = 178
#  Mass ratios :  [ 1.          0.13036568]
#  3 mergers at nout = 175
#  Mass ratios :  [ 1.          0.75566214  0.00312168]
# analyzing merger events of galaxy  122701
#  3 mergers at nout = 182
#  Mass ratios :  [ 1.          0.07632861  0.01607754]
#  2 mergers at nout = 179
#  Mass ratios :  [ 1.          0.06889071]
#  2 mergers at nout = 89
#  Mass ratios :  [ 1.          0.85916013]
# analyzing merger events of galaxy  122729
# analyzing merger events of galaxy  122759
# analyzing merger events of galaxy  122899
# analyzing merger events of galaxy  122683
#  2 mergers at nout = 173
#  Mass ratios :  [ 1.          0.00327692]
#  2 mergers at nout = 160
#  Mass ratios :  [ 1.          0.00192462]
#  2 mergers at nout = 143
#  Mass ratios :  [ 1.          0.01276282]
#  2 mergers at nout = 138
#  Mass ratios :  [ 1.          0.00261813]
#  3 mergers at nout = 134
#  Mass ratios :  [ 1.          0.12001316  0.01806032]
#  2 mergers at nout = 116
#  Mass ratios :  [ 1.          0.01063257]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.01735197]
#  2 mergers at nout = 102
#  Mass ratios :  [ 1.          0.31616682]
#  2 mergers at nout = 95
#  Mass ratios :  [ 1.          0.01083179]
#  2 mergers at nout = 93
#  Mass ratios :  [ 1.          0.01151844]
# analyzing merger events of galaxy  122705
# analyzing merger events of galaxy  122739
#  2 mergers at nout = 133
#  Mass ratios :  [ 1.          0.14950383]
# analyzing merger events of galaxy  122766
#  2 mergers at nout = 102
#  Mass ratios :  [ 1.          0.88874602]
# analyzing merger events of galaxy  123025
#  2 mergers at nout = 185
#  Mass ratios :  [ 1.          0.22578096]
#  2 mergers at nout = 145
#  Mass ratios :  [ 1.          0.13016221]
#  2 mergers at nout = 143
#  Mass ratios :  [ 1.          0.82322186]
# analyzing merger events of galaxy  122674
# analyzing merger events of galaxy  122695
#  2 mergers at nout = 144
#  Mass ratios :  [ 1.          0.01871724]
#  2 mergers at nout = 142
#  Mass ratios :  [ 1.          0.74062258]
#  2 mergers at nout = 109
#  Mass ratios :  [ 1.          0.05442227]
# analyzing merger events of galaxy  122717
# analyzing merger events of galaxy  122753
#  2 mergers at nout = 134
#  Mass ratios :  [ 1.          0.00763497]
#  2 mergers at nout = 131
#  Mass ratios :  [ 1.        0.038885]
#  2 mergers at nout = 129
#  Mass ratios :  [ 1.          0.01218641]
#  2 mergers at nout = 107
#  Mass ratios :  [ 1.          0.05121187]
# analyzing merger events of galaxy  122784
#  2 mergers at nout = 109
#  Mass ratios :  [ 1.          0.75927979]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.         0.1689955]
#  2 mergers at nout = 95
#  Mass ratios :  [ 1.          0.65346497]
# analyzing merger events of galaxy  122679
#  2 mergers at nout = 171
#  Mass ratios :  [ 1.         0.0527861]
#  2 mergers at nout = 134
#  Mass ratios :  [ 1.          0.00612748]
#  2 mergers at nout = 122
#  Mass ratios :  [ 1.          0.02308624]
# analyzing merger events of galaxy  122698
# analyzing merger events of galaxy  122728
#  2 mergers at nout = 157
#  Mass ratios :  [ 1.          0.87340885]
#  2 mergers at nout = 88
#  Mass ratios :  [ 1.          0.05481379]
# analyzing merger events of galaxy  122758
#  2 mergers at nout = 167
#  Mass ratios :  [ 1.          0.03305642]
#  2 mergers at nout = 136
#  Mass ratios :  [ 1.          0.10096993]
#  2 mergers at nout = 96
#  Mass ratios :  [ 1.          0.29997903]
# analyzing merger events of galaxy  122835
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.46582538]
# analyzing merger events of galaxy  122670
#  2 mergers at nout = 178
#  Mass ratios :  [ 1.          0.02186884]
#  2 mergers at nout = 175
#  Mass ratios :  [ 1.          0.00974594]
#  2 mergers at nout = 153
#  Mass ratios :  [ 1.          0.06588086]
#  2 mergers at nout = 137
#  Mass ratios :  [ 1.          0.02683324]
#  2 mergers at nout = 124
#  Mass ratios :  [ 1.          0.75193453]
# analyzing merger events of galaxy  122692
# analyzing merger events of galaxy  122710
#  2 mergers at nout = 124
#  Mass ratios :  [ 1.          0.02760943]
# analyzing merger events of galaxy  122750
#  2 mergers at nout = 135
#  Mass ratios :  [ 1.          0.31499475]
# analyzing merger events of galaxy  122773
#  2 mergers at nout = 93
#  Mass ratios :  [ 1.          0.05695222]
# analyzing merger events of galaxy  123047
# analyzing merger events of galaxy  122672
#  2 mergers at nout = 117
#  Mass ratios :  [ 1.          0.00299203]
#  2 mergers at nout = 104
#  Mass ratios :  [ 1.          0.02014628]
#  2 mergers at nout = 98
#  Mass ratios :  [ 1.          0.00249824]
# analyzing merger events of galaxy  122693
#  2 mergers at nout = 102
#  Mass ratios :  [ 1.         0.5230943]
# analyzing merger events of galaxy  122714
#  2 mergers at nout = 121
#  Mass ratios :  [ 1.          0.02242619]
#  2 mergers at nout = 96
#  Mass ratios :  [ 1.          0.24172425]
# analyzing merger events of galaxy  122751
#  2 mergers at nout = 96
#  Mass ratios :  [ 1.          0.00334153]
# analyzing merger events of galaxy  122776
#  2 mergers at nout = 133
#  Mass ratios :  [ 1.          0.09200241]
# analyzing merger events of galaxy  123051
#  2 mergers at nout = 184
#  Mass ratios :  [ 1.          0.08436526]
#  2 mergers at nout = 134
#  Mass ratios :  [ 1.          0.01459096]
#  2 mergers at nout = 105
#  Mass ratios :  [ 1.          0.22731985]
# analyzing merger events of galaxy  122673
#  2 mergers at nout = 119
#  Mass ratios :  [ 1.          0.67035836]
# analyzing merger events of galaxy  122694
#  2 mergers at nout = 177
#  Mass ratios :  [ 1.          0.04866778]
#  2 mergers at nout = 93
#  Mass ratios :  [ 1.          0.12617081]
#  2 mergers at nout = 92
#  Mass ratios :  [ 1.          0.01595504]
# analyzing merger events of galaxy  122715
# analyzing merger events of galaxy  122752
#  2 mergers at nout = 116
#  Mass ratios :  [ 1.          0.34280258]
#  2 mergers at nout = 112
#  Mass ratios :  [ 1.          0.01274181]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.40347621]
#  2 mergers at nout = 105
#  Mass ratios :  [ 1.          0.90615124]
#  3 mergers at nout = 102
#  Mass ratios :  [ 1.          0.27451468  0.05098307]
#  2 mergers at nout = 92
#  Mass ratios :  [ 1.          0.48672423]
# analyzing merger events of galaxy  122780
#  2 mergers at nout = 94
#  Mass ratios :  [ 1.          0.33652887]
# analyzing merger events of galaxy  123054
#  2 mergers at nout = 164
#  Mass ratios :  [ 1.          0.05781903]
#  2 mergers at nout = 159
#  Mass ratios :  [ 1.          0.01928674]
# analyzing merger events of galaxy  122668
#  2 mergers at nout = 177
#  Mass ratios :  [ 1.          0.01372126]
#  2 mergers at nout = 175
#  Mass ratios :  [ 1.          0.00406753]
#  3 mergers at nout = 160
#  Mass ratios :  [ 1.          0.02046413  0.01313273]
#  2 mergers at nout = 156
#  Mass ratios :  [ 1.          0.00218218]
#  3 mergers at nout = 154
#  Mass ratios :  [ 1.          0.13328715  0.02582956]
#  2 mergers at nout = 143
#  Mass ratios :  [ 1.          0.00341027]
#  2 mergers at nout = 141
#  Mass ratios :  [ 1.          0.08072044]
#  2 mergers at nout = 129
#  Mass ratios :  [ 1.         0.1051835]
#  2 mergers at nout = 117
#  Mass ratios :  [ 1.          0.00759711]
#  3 mergers at nout = 97
#  Mass ratios :  [ 1.          0.27686304  0.07979721]
# analyzing merger events of galaxy  122690
#  2 mergers at nout = 174
#  Mass ratios :  [ 1.          0.26114842]
# analyzing merger events of galaxy  122709
#  2 mergers at nout = 149
#  Mass ratios :  [ 1.          0.03587648]
#  2 mergers at nout = 147
#  Mass ratios :  [ 1.        0.101116]
# analyzing merger events of galaxy  122747
#  2 mergers at nout = 166
#  Mass ratios :  [ 1.          0.18031096]
#  3 mergers at nout = 160
#  Mass ratios :  [ 1.          0.99636376  0.25245804]
#  2 mergers at nout = 127
#  Mass ratios :  [ 1.          0.05507012]
#  2 mergers at nout = 97
#  Mass ratios :  [ 1.          0.28972667]
# analyzing merger events of galaxy  122772
#  2 mergers at nout = 119
#  Mass ratios :  [ 1.          0.73248279]
#  2 mergers at nout = 95
#  Mass ratios :  [ 1.          0.17707674]
# analyzing merger events of galaxy  123039
#  2 mergers at nout = 149
#  Mass ratios :  [ 1.          0.01901604]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.03048346]
# analyzing merger events of galaxy  122665
#  2 mergers at nout = 186
#  Mass ratios :  [ 1.         0.0136716]
#  2 mergers at nout = 177
#  Mass ratios :  [ 1.          0.01322301]
#  2 mergers at nout = 121
#  Mass ratios :  [ 1.          0.00298723]
#  2 mergers at nout = 107
#  Mass ratios :  [ 1.          0.01458638]
#  2 mergers at nout = 102
#  Mass ratios :  [ 1.          0.00859037]
#  2 mergers at nout = 97
#  Mass ratios :  [ 1.          0.03806051]
#  2 mergers at nout = 94
#  Mass ratios :  [ 1.          0.00453108]
# analyzing merger events of galaxy  122687
# analyzing merger events of galaxy  122706
# analyzing merger events of galaxy  122745
#  2 mergers at nout = 168
#  Mass ratios :  [ 1.          0.01262841]
#  2 mergers at nout = 164
#  Mass ratios :  [ 1.          0.02049702]
#  2 mergers at nout = 145
#  Mass ratios :  [ 1.          0.04343958]
#  2 mergers at nout = 121
#  Mass ratios :  [ 1.          0.05002541]
# analyzing merger events of galaxy  122767
# analyzing merger events of galaxy  123037
#  3 mergers at nout = 185
#  Mass ratios :  [ 0.         1.         0.4520548]
#  2 mergers at nout = 184
#  Mass ratios :  [ 0.  1.]
#  2 mergers at nout = 183
#  Mass ratios :  [ 1.          0.12300102]
#  5 mergers at nout = 182
#  Mass ratios :  [ 1.          0.32802948  0.0533093   0.02874628  0.0054156 ]
#  3 mergers at nout = 181
#  Mass ratios :  [ 1.          0.09064903  0.00559878]
#  3 mergers at nout = 180
#  Mass ratios :  [ 1.          0.01989169  0.0098126 ]
#  2 mergers at nout = 161
#  Mass ratios :  [ 1.          0.03304198]
#  2 mergers at nout = 160
#  Mass ratios :  [ 1.          0.01032536]
#  2 mergers at nout = 154
#  Mass ratios :  [ 1.          0.00459974]
#  2 mergers at nout = 150
#  Mass ratios :  [ 1.          0.06688395]
#  2 mergers at nout = 131
#  Mass ratios :  [ 1.          0.02353852]
#  2 mergers at nout = 127
#  Mass ratios :  [ 1.          0.44994545]
#  3 mergers at nout = 118
#  Mass ratios :  [ 1.          0.20863654  0.14873098]
#  2 mergers at nout = 110
#  Mass ratios :  [ 1.          0.39875409]
#  2 mergers at nout = 108
#  Mass ratios :  [ 1.          0.26254863]
#  2 mergers at nout = 104
#  Mass ratios :  [ 1.          0.36221489]

# %%
idx
# Out:
# array([], dtype=int64)
